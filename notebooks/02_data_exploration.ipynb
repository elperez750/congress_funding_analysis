# %% [markdown]
# # Import pandas and ast

# %%
import pandas as pd
import ast

# %% [markdown]
# # Loading in data and parsing entries with lists of objects

# %%
main_member_df = pd.read_csv('../congress_members_2024.csv')

# Creating index for members later on
main_member_df['member_id'] = main_member_df.index


# Parsing string representation back into list
main_member_df['all_industries_parsed'] = main_member_df['all_industries'].apply(ast.literal_eval)
main_member_df['all_contributors_parsed'] = main_member_df['all_contributors'].apply(ast.literal_eval)
main_member_df['all_funding_types_parsed'] = main_member_df['funding_type'].apply(ast.literal_eval)
main_member_df['total_vs_avg_raised_parsed'] = main_member_df['total_vs_avg_raised'].apply(ast.literal_eval)


# Fields for this are
# contribution_type, contribution_amount, contribution_percentage


# year, total_raised_by_congressman, average_raised
main_member_df['total_vs_avg_raised_parsed']
# Out:
# 0      [{'year': 2014, 'total_raised_by_congressman':...
# 1      [{'year': 1996, 'total_raised_by_congressman':...
# 2      [{'year': 2012, 'total_raised_by_congressman':...
# 3      [{'year': 2022, 'total_raised_by_congressman':...
# 4      [{'year': 2012, 'total_raised_by_congressman':...
#                              ...
# 534    [{'year': 2010, 'total_raised_by_congressman':...
# 535    [{'year': 1990, 'total_raised_by_congressman':...
# 536    [{'year': 2022, 'total_raised_by_congressman':...
# 537    [{'year': 2010, 'total_raised_by_congressman':...
# 538    [{'year': 2014, 'total_raised_by_congressman':...
# Name: total_vs_avg_raised_parsed, Length: 539, dtype: object

# %% [markdown]
# # Helper Functions to convert string to integers

# %%
def convert_money_to_int(str_money):
    if str_money[0] == '-':
        str_money = str_money[1:]
        return -int(str_money.strip('$').replace(',', ''))


    return int(str_money.strip('$').replace(',', ''))


def convert_fields_to_int(df):

    print(type(df))

    df['total'] = df['total'].apply(convert_money_to_int)
    df['individuals'] = df['individuals'].apply(convert_money_to_int)
    df['pacs'] = df['pacs'].apply(convert_money_to_int)

    return df

# %% [markdown]
# # Create industries dataframe to link back to main dataframe

# %%
industries_list = []
industries_df = None

for idx, row in main_member_df.iterrows():
    member_id = row['member_id']
    for industry in row['all_industries_parsed']:
        industries_list.append(
            {
                'member_id': member_id,
                'industry': str(industry['industry']),
                'total': str(industry['total']),
                'individuals': str(industry['individuals']),
                'pacs': str(industry['pacs'])

            }
        )

    industries_df = pd.DataFrame(industries_list)

industries_df = convert_fields_to_int(industries_df)
industries_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    member_id               industry  total  individuals   pacs
# 0          0       Commercial Banks  48245         3745  44500
# 1          0   Public Sector Unions  44000         1000  43000
# 2          0  Building Trade Unions  40500            0  40500
# 3          0              Insurance  36980          980  36000
# 4          0   Health Professionals  32720         7220  25500

# %% [markdown]
# # Create contributors dataframe for members

# %%
contributors_list = []
contributors_df = None

for idx, row in main_member_df.iterrows():
    member_id = row['member_id']
    for contributor in row['all_contributors_parsed']:
        contributors_list.append(
            {
                'member_id': member_id,
                'contributor': str(contributor['contributor']),
                'total': str(contributor['total']),
                'individuals': str(contributor['individuals']),
                'pacs': str(contributor['pacs'])

            }
        )
    contributors_df = pd.DataFrame(contributors_list)


contributors_df = convert_fields_to_int(contributors_df)
contributors_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    member_id                                        contributor  total  \
# 0          0                                        Duke Energy  10350
# 1          0                             American Crystal Sugar  10000
# 2          0  American Federation of State/Cnty/Munic Employees  10000
# 3          0                    American Federation of Teachers  10000
# 4          0                      Blue Cross & Blue Shield Assn  10000
#
#    individuals   pacs
# 0          350  10000
# 1            0  10000
# 2            0  10000
# 3            0  10000
# 4            0  10000

# %% [markdown]
# # Create all funding types for individual dataframe

# %%
all_funding_list = []
all_funding_df = None

for idx, row in main_member_df.iterrows():
    member_id = row['member_id']
    for funding in row['all_funding_types_parsed']:
        # contribution_type, contribution_amount, contribution_percentage
        all_funding_list.append(
            {
                'member_id': member_id,
                'contribution_type': str(funding['contribution_type']),
                'contribution_amount': funding['contribution_amount'],
                'contribution_percent': funding['contribution_percent'],

            }
        )
    all_funding_df = pd.DataFrame(all_funding_list)


all_funding_df.head(20)
# Out:
#     member_id                   contribution_type  contribution_amount  \
# 0           0                   pac_contributions               516244
# 1           0      large_individual_contributions               164760
# 2           0  small_individual_contributions_200                34494
# 3           0             candidate_selffinancing                    0
# 4           0                               other                 -560
# 5           1                   pac_contributions               795500
# 6           1      large_individual_contributions               611924
# 7           1                               other                39797
# 8           1  small_individual_contributions_200                23428
# 9           1             candidate_selffinancing                    0
# 10          2                   pac_contributions              2514458
# 11          2      large_individual_contributions              2215334
# 12          2                               other               855113
# 13          2  small_individual_contributions_200               223890
# 14          2             candidate_selffinancing                    0
# 15          3                   pac_contributions               594939
# 16          3      large_individual_contributions               566512
# 17          3                               other               106274
# 18          3  small_individual_contributions_200                36162
# 19          3             candidate_selffinancing                    0
#
#     contribution_percent
# 0                     72
# 1                     23
# 2                      4
# 3                      0
# 4                      0
# 5                     54
# 6                     41
# 7                      2
# 8                      1
# 9                      0
# 10                    43
# 11                    38
# 12                    14
# 13                     3
# 14                     0
# 15                    45
# 16                    43
# 17                     8
# 18                     2
# 19                     0

# %% [markdown]
# # Get total vs average raised by congress member dataframe

# %%
# year, total_raised_by_congressman, average_raised

total_vs_avg_list = []
total_vs_avg_df = None

for idx, row in main_member_df.iterrows():
    member_id = row['member_id']
    for entry in row['total_vs_avg_raised_parsed']:
        total_vs_avg_list.append(
            {
                'member_id': member_id,
                'year': entry['year'],
                'total_raised_by_congress_member': entry['total_raised_by_congressman'],
                'average_raised_by_congress_member': entry['average_raised'],

            }
        )
    total_vs_avg_df = pd.DataFrame(total_vs_avg_list)


total_vs_avg_df.head(30)
# Out:
#     member_id  year  total_raised_by_congress_member  \
# 0           0  2014                         766900.0
# 1           0  2016                         922090.0
# 2           0  2018                         589690.0
# 3           0  2020                         824120.0
# 4           0  2022                         947660.0
# 5           0  2024                         714940.0
# 6           1  1996                         759350.0
# 7           1  1998                        1510000.0
# 8           1  2000                        1640000.0
# 9           1  2002                         712480.0
# 10          1  2004                         748910.0
# 11          1  2006                         715800.0
# 12          1  2008                         666970.0
# 13          1  2010                         828590.0
# 14          1  2012                        1250000.0
# 15          1  2014                        1180000.0
# 16          1  2016                        1430000.0
# 17          1  2018                        1550000.0
# 18          1  2020                        1260000.0
# 19          1  2022                        1540000.0
# 20          1  2024                        1470000.0
# 21          2  2012                         461840.0
# 22          2  2014                        2230000.0
# 23          2  2016                        2890000.0
# 24          2  2018                        2720000.0
# 25          2  2020                        2480000.0
# 26          2  2022                        3200000.0
# 27          2  2024                        5810000.0
# 28          3  2022                        1040000.0
# 29          3  2024                        1300000.0
#
#     average_raised_by_congress_member
# 0                             1720000
# 1                             1750000
# 2                             2190000
# 3                             2640000
# 4                             3060000
# 5                             3310000
# 6                              747230
# 7                              890710
# 8                             1010000
# 9                              980640
# 10                            1200000
# 11                            1360000
# 12                            1430000
# 13                            1620000
# 14                            1760000
# 15                            1720000
# 16                            1750000
# 17                            2190000
# 18                            2640000
# 19                            3060000
# 20                            3310000
# 21                            1760000
# 22                            1720000
# 23                            1750000
# 24                            2190000
# 25                            2640000
# 26                            3060000
# 27                            3310000
# 28                            3060000
# 29                            3310000

# %%
columns_to_drop = ['all_industries', 'all_contributors', 'total_vs_avg_raised', 'funding_type', 'all_industries_parsed', 'all_contributors_parsed', 'total_vs_avg_raised_parsed', 'all_funding_types_parsed']

main_member_df.drop(columns = columns_to_drop, inplace = True)


main_member_df.head()
# Out:
#                                                 link               name  \
# 0  https://www.opensecrets.org/members-of-congres...         Alma Adams
# 1  https://www.opensecrets.org/members-of-congres...  Robert B Aderholt
# 2  https://www.opensecrets.org/members-of-congres...       Pete Aguilar
# 3  https://www.opensecrets.org/members-of-congres...        Mark Alford
# 4  https://www.opensecrets.org/members-of-congres...    Richard W Allen
#
#             state chamber       party   raised    spent  cash_on_hand  \
# 0  North Carolina   House    Democrat   714938   684971        573409
# 1         Alabama   House  Republican  1470649  1663198        966896
# 2      California   House    Democrat  5808795  4739480       2649071
# 3        Missouri   House  Republican  1303886  1140087        217408
# 4         Georgia   House  Republican  1217539   901827       1174956
#
#      debts      top_industry                      top_contributor  \
# 0        0  Commercial Banks                          Duke Energy
# 1        0      Misc Defense  American Israel Public Affairs Cmte
# 2        0        Pro-Israel  American Israel Public Affairs Cmte
# 3        0           Retired                      Plz Aeroscience
# 4  1639945           Retired  American Israel Public Affairs Cmte
#
#   top_industry_number top_contributor_number  first_election  election_type  \
# 0             $48,245                $10,350            2014  Next Election
# 1            $141,034                $34,804            1996  Next Election
# 2            $673,463               $620,898            2014  Next Election
# 3             $91,292                $26,400            2022  Next Election
# 4             $96,386                $25,550            2014  Next Election
#
#    election_year  member_id
# 0         2024.0          0
# 1         2024.0          1
# 2         2024.0          2
# 3         2024.0          3
# 4         2024.0          4

# %% [markdown]
# # Party and Ideology Analysis

# %% [markdown]
# # Party information

# %%
# Finding who raised the most by party
raised_by_party = main_member_df.groupby('party')['raised'].sum()


# How much members for each party
party_counts = main_member_df['party'].value_counts()


# Average spending per party
spending_by_party = main_member_df.groupby('party')[['raised', 'spent']].mean()

# %% [markdown]
# # Geographic patterns

# %%
# States the raise the most amount of money
main_member_df.groupby('state')['raised'].sum().nlargest(20)


# Top industries for each state
top_industry_per_state = main_member_df.groupby('state')['top_industry'].apply(lambda x: x.value_counts().nlargest(1))

print(top_industry_per_state)
# Out:
# state
# Alabama               Retired                                3
# Alaska                Retired                                2
# American Samoa        Leadership PACs                        1
# Arizona               Retired                                9
# Arkansas              Crop Production & Basic Processing     2
# California            Retired                               15
# Colorado              Retired                                6
# Connecticut           Retired                                3
# Delaware              Pharmaceuticals/Health Products        1
# District of Columbia  Transportation Unions                  1
# Florida               Retired                               10
# Georgia               Retired                                5
# Guam                  Leadership PACs                        1
# Hawaii                Retired                                2
# Idaho                 Securities & Investment                1
# Illinois              Retired                                6
# Indiana               Retired                                4
# Iowa                  Retired                                5
# Kansas                Retired                                2
# Kentucky              Retired                                4
# Louisiana             Republican/Conservative                2
# Maine                 Retired                                4
# Maryland              Retired                                2
# Massachusetts         Retired                                4
# Michigan              Retired                                8
# Minnesota             Retired                                7
# Mississippi           Leadership PACs                        1
# Missouri              Retired                                3
# Montana               Retired                                4
# Nebraska              Pro-Israel                             1
# Nevada                Retired                                3
# New Hampshire         Retired                                4
# New Jersey            Retired                                6
# New Mexico            Retired                                5
# New York              Securities & Investment                9
# North Carolina        Retired                                8
# North Dakota          Retired                                1
# Ohio                  Insurance                              3
# Oklahoma              Oil & Gas                              4
# Oregon                Retired                                5
# Pennsylvania          Retired                                6
# Puerto Rico           Health Professionals                   1
# Rhode Island          Lawyers/Law Firms                      2
# South Carolina        Retired                                4
# South Dakota          Securities & Investment                2
# Tennessee             Retired                                5
# Texas                 Retired                               15
# Utah                  Retired                                3
# Vermont               Retired                                2
# Virgin Islands        Leadership PACs                        1
# Virginia              Retired                                8
# Washington            Retired                                7
# West Virginia         Retired                                1
# Wisconsin             Retired                                7
# Wyoming               Securities & Investment                1
# Name: top_industry, dtype: int64

# %% [markdown]
# # Industry Influence

# %%
# Finding what industries contribute the most
top_industries = industries_df.groupby('industry')['total'].sum().nlargest(10)
top_industries
# Out:
# industry
# Retired                    586889379
# Securities & Investment    166595294
# Lawyers/Law Firms          111412208
# Republican/Conservative     94353384
# Real Estate                 79903156
# Democratic/Liberal          62255173
# Education                   54710754
# Health Professionals        52612941
# Leadership PACs             48506379
# Pro-Israel                  30066449
# Name: total, dtype: int64

# %% [markdown]
# # House vs Senate

# %%
# Total raised by senate vs total raised by house
total_raised_chamber = main_member_df.groupby('chamber')['raised'].sum()


# Total members for each chamber
total_for_chamber = main_member_df['chamber'].value_counts()


average_raised_by_house_member = total_raised_chamber[0] / total_for_chamber[0]
average_raised_by_senate_member = total_raised_chamber[1] / total_for_chamber[1]




# top industry for senators
top_industries_senate = main_member_df[main_member_df['chamber'] == 'Senate']['top_contributor'].value_counts()

# Top industry for house members
top_industries_house = main_member_df[main_member_df['chamber'] == 'House']['top_contributor'].value_counts()


top_industries_senate
# Out:
# top_contributor
# American Israel Public Affairs Cmte         23
# Senate Conservatives Fund                    6
# Blackstone Group                             5
# Apollo Global Management                     5
# Pro-Israel America PAC                       3
# EMILY's List                                 3
# Google Inc                                   3
# Stephens Inc                                 2
# National Republican Senatorial Cmte          2
# JStreetPAC                                   2
# Club for Growth                              2
# Beasley, Allen et al                         2
# Lockheed Martin                              1
# University of Washington                     1
# ConocoPhillips                               1
# Building Bridges Pac                         1
# University of Michigan                       1
# Bloomberg Lp                                 1
# Yale University                              1
# steptoe LLP                                  1
# Donohoe Companies                            1
# University of Wisconsin/Madison              1
# Freedom Fund                                 1
# Charter Communications                       1
# Kent Companies                               1
# Goldman Sachs                                1
# Emily's List                                 1
# University Of Minnesota                      1
# Dow Inc                                      1
# Trident Seafoods                             1
# Hmtx Industries LLC                          1
# Massachusetts Institute of Technology        1
# League of Conservation Voters                1
# Seemann Composites                           1
# Nueterra Capital                             1
# NorPAC                                       1
# Lowenstein Sandler Llp                       1
# Ackerman Oil                                 1
# Ohio State University                        1
# Williams Companies                           1
# Welsh, Carson et al                          1
# Young, Conaway et al                         1
# UnitedHealth Group                           1
# Power Rogers LLP                             1
# Negocio Propio                               1
# WilmerHale LLP                               1
# Republican Jewish Coalition                  1
# University of New Mexico                     1
# University of Hawaii                         1
# Welsh, Carson et al                          1
# Covington & Burling                          1
# University of Arizona                        1
# National Assn of Broadcasters                1
# No Labels Problem Solvers                    1
# Nike Inc                                     1
# Name: count, dtype: int64

# %% [markdown]
# # Top industries per party per state

# %%
main_member_df.head()
top_industry_per_party_per_state = main_member_df.groupby(['state','party'])['top_industry'].apply(lambda x: x.value_counts().nlargest(1))


top_industry_per_party_per_state['Texas']
# Out:
# party
# Democrat    Oil & Gas     4
# Republican  Retired      13
# Name: top_industry, dtype: int64

# %% [markdown]
# # Longest tenured members in congress

# %%
earliest_year = main_member_df['first_election'].min()
longest_tenured_member = main_member_df[main_member_df['first_election'] == earliest_year]

longest_tenured_member
# Out:
#                                                   link            name  \
# 193  https://www.opensecrets.org/members-of-congres...  Chuck Grassley
# 408  https://www.opensecrets.org/members-of-congres...      Hal Rogers
# 457  https://www.opensecrets.org/members-of-congres...     Chris Smith
#
#           state chamber       party   raised   spent  cash_on_hand  debts  \
# 193        Iowa  Senate  Republican   597606  706128        332900      0
# 408    Kentucky   House  Republican  1052276  793990        971251      0
# 457  New Jersey   House  Republican   838536  700904        364065      0
#
#     top_industry                      top_contributor top_industry_number  \
# 193      Retired  National Republican Senatorial Cmte          $1,665,154
# 408    Lobbyists       Cornerstone Government Affairs             $97,711
# 457      Retired  American Israel Public Affairs Cmte             $73,282
#
#     top_contributor_number  first_election  election_type  election_year  \
# 193                $52,200            1980  Next Election         2028.0
# 408                $29,000            1980  Next Election         2024.0
# 457                $27,500            1980  Next Election         2024.0
#
#      member_id
# 193        193
# 408        408
# 457        457

# %% [markdown]
# # Average increase by member per year

# %%
# compute mean year-to-year change per member and broadcast to all their rows
total_vs_avg_df['avg_growth_for_member'] = (
    total_vs_avg_df.groupby('member_id')['total_raised_by_congress_member']
      .transform(lambda s: s.diff().mean())
)


largest_average_growth = total_vs_avg_df['avg_growth_for_member'].max()
member_with_largest_growth = total_vs_avg_df[total_vs_avg_df['avg_growth_for_member'] == largest_average_growth]

member_with_largest_growth
# Out:
#     member_id  year  total_raised_by_congress_member  \
# 37          5  2018                        5850000.0
# 38          5  2020                        5670000.0
# 39          5  2022                        3390000.0
# 40          5  2024                       92580000.0
#
#     average_raised_by_congress_member  avg_growth_for_member
# 37                            2190000             28910000.0
# 38                            2640000             28910000.0
# 39                            3060000             28910000.0
# 40                            3310000             28910000.0
