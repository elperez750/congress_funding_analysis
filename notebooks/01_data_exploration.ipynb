# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from click import style

# %% [markdown]
# **This will set up our selenium scraper in order to get information from the page**

# %%
#url = 'https://www.opensecrets.org/members-of-congress/members-list?cong_no=118&cycle=2024&sort=N'
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service)


driver.get('https://www.opensecrets.org/members-of-congress/members-list?cong_no=118&cycle=2024&sort=N')

print('Page title', driver.title)

html_content = driver.page_source
# Out:
# Page title Members of the 118th Congress • OpenSecrets

# %% [markdown]
# This will initialize our Beautiful Soup scraper and get all the congresspeople rows that contains all the basic information

# %%
soup = BeautifulSoup(html_content, 'html.parser')
print("Title:", soup.title.text)
print("Number of tables:", len(soup.find_all('table')))
print("Number of divs:", len(soup.find_all('div')))
from selenium.webdriver.common.by import By


#print('Number of table rows', len(soup.find_all('tr')))

table_body = soup.find('tbody')

#print(table_body)

congress_people_basic_info = table_body.find_all('tr')


next_button = driver.find_element(By.CSS_SELECTOR, "a.paginate_button.next")
print("helloooo", next_button.get_attribute('outerHTML'))
driver.execute_script("arguments[0].click();", next_button)
# Out:
# Title: Members of the 118th Congress • OpenSecrets
# Number of tables: 1
# Number of divs: 270
# helloooo <a class="paginate_button next" aria-controls="DataTables_Table_0" data-dt-idx="7" tabindex="0" id="DataTables_Table_0_next">Next</a>
# None

# %% [markdown]
# Functions to convert money from string to int

# %%
# Function to parse strings such as '$1,100,900'
def parse_currency_string(value):
    if value[0] == "-":
        return -1 * int(value[1:].strip('$').replace(',', ''))

    return int(value.strip('$').replace(',', ''))


# This function will be similar but will parse string such as '$11.7M' or '$11.7B'
def parse_abbreviated_number(string_amount):
    scale_factors = {'M': 1_000_000, 'K': 1_000, 'B': 1_000_000_000}

    cleaned_string = string_amount.strip().strip('$')
    try:

        scale = cleaned_string[-1].upper()
        numerical_part = cleaned_string[:-1]
        factor = scale_factors[scale]

        return int(float(numerical_part) * factor)

    except (KeyError, ValueError, IndexError) as e:
        print(f"Error: {e}")
        return None


print(parse_abbreviated_number('$11.7M'))
print(parse_currency_string('-$1,100,900'))
# Out:
# 11700000
# -1100900

# %% [markdown]
# **getting basic information from the congressman**

# %%
congress_information = []
base_url = 'https://www.opensecrets.org'
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
driver.get("https://www.opensecrets.org/members-of-congress/members-list?cong_no=118&cycle=2024&sort=N")


while True:
    try:
        html_content = driver.page_source
        soup = BeautifulSoup(html_content, 'html.parser')
        table_body = soup.find('tbody')
        congress_people_basic_info = table_body.find_all('tr')
        for entry in congress_people_basic_info:
            #print(entry)
            congressman_information = {}
            row = entry.find_all('td')
            #print("This is the row", row)
            link = entry.find_all('a')[0]['href']
            #print("This is the link", link)
            full_link = base_url + link


            congressman_information['link'] = full_link
            congressman_information['name'] = row[0].find('a').text.strip()
            congressman_information['state'] = row[1].text
            congressman_information['chamber'] = row[2].text
            congressman_information['party'] = row[3].text
            congressman_information['raised'] = parse_currency_string(row[4].text)
            congressman_information['spent'] = parse_currency_string(row[5].text)
            congressman_information['cash_on_hand'] = parse_currency_string(row[6].text)
            congressman_information['debts'] = parse_currency_string(row[7].text)

            congress_information.append(congressman_information)


            print(congressman_information)

        next_button = driver.find_element(By.CSS_SELECTOR, "a.paginate_button.next")


        if "disabled" in next_button.get_attribute("class"):
            break

        if next_button:
            driver.execute_script("arguments[0].click();", next_button)

            WebDriverWait(driver, 10).until(
                    EC.presence_of_element_located((By.TAG_NAME, "tbody"))
            )

        else:
            break


    except (KeyError, ValueError, IndexError) as e:
        print(f"Error: {e}")



required = ["link","name","state","chamber","party","raised","spent","cash_on_hand","debts"]
num_fields = len(required)

issues = []

for i, m in enumerate(congress_information):
    missing = [k for k in required if k not in m]
    empties = [k for k in required if k in m and (m[k] in (None, "", []))]
    wrong_types = []
    # simple type checks
    for k in ["raised","spent","cash_on_hand","debts"]:
        if k in m and not isinstance(m[k], (int, float)):
            wrong_types.append(k)
    # quick link sanity
    bad_link = ("link" in m) and not (isinstance(m["link"], str) and m["link"].startswith("https://www.opensecrets.org/"))

    if missing or empties or wrong_types or bad_link:
        issues.append({
            "index": i,
            "name": m.get("name"),
            "missing": missing,
            "empty": empties,
            "wrong_types": wrong_types,
            "bad_link": bad_link,
        })

print(f"Total objects: {len(congress_information)}")
print(f"With issues:   {len(issues)}")
print(issues[:5])  # peek at first few problems


for index, member in enumerate(congress_information):

    if member['name'] == 'Earl Blumenauer':
        print(f"{index}: {member['name']}")
# Out:
# {'link': 'https://www.opensecrets.org/members-of-congress/adams-alma/summary?cid=N00035451&cycle=2024', 'name': 'Alma Adams', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Democrat', 'raised': 714938, 'spent': 684971, 'cash_on_hand': 573409, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/aderholt-robert-b/summary?cid=N00003028&cycle=2024', 'name': 'Robert B Aderholt', 'state': 'Alabama', 'chamber': 'House', 'party': 'Republican', 'raised': 1470649, 'spent': 1663198, 'cash_on_hand': 966896, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/aguilar-pete/summary?cid=N00033997&cycle=2024', 'name': 'Pete Aguilar', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 5808795, 'spent': 4739480, 'cash_on_hand': 2649071, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/alford-mark/summary?cid=N00049617&cycle=2024', 'name': 'Mark Alford', 'state': 'Missouri', 'chamber': 'House', 'party': 'Republican', 'raised': 1303886, 'spent': 1140087, 'cash_on_hand': 217408, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/allen-richard-w/summary?cid=N00033720&cycle=2024', 'name': 'Richard W Allen', 'state': 'Georgia', 'chamber': 'House', 'party': 'Republican', 'raised': 1217539, 'spent': 901827, 'cash_on_hand': 1174956, 'debts': 1639945}
# {'link': 'https://www.opensecrets.org/members-of-congress/allred-colin/summary?cid=N00040989&cycle=2024', 'name': 'Colin Allred', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 92580216, 'spent': 92436082, 'cash_on_hand': 144134, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/amo-gabe/summary?cid=N00052615&cycle=2024', 'name': 'Gabe Amo', 'state': 'Rhode Island', 'chamber': 'House', 'party': 'Democrat', 'raised': 2567783, 'spent': 1633136, 'cash_on_hand': 934647, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/amodei-mark/summary?cid=N00031177&cycle=2024', 'name': 'Mark Amodei', 'state': 'Nevada', 'chamber': 'House', 'party': 'Republican', 'raised': 1277055, 'spent': 1195668, 'cash_on_hand': 361040, 'debts': 9000}
# {'link': 'https://www.opensecrets.org/members-of-congress/armstrong-kelly/summary?cid=N00042868&cycle=2024', 'name': 'Kelly Armstrong', 'state': 'North Dakota', 'chamber': 'House', 'party': 'Republican', 'raised': 661893, 'spent': 939157, 'cash_on_hand': 0, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/arrington-jodey/summary?cid=N00038285&cycle=2024', 'name': 'Jodey Arrington', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 3247143, 'spent': 2684278, 'cash_on_hand': 1884196, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/auchincloss-jake/summary?cid=N00045506&cycle=2024', 'name': 'Jake Auchincloss', 'state': 'Massachusetts', 'chamber': 'House', 'party': 'Democrat', 'raised': 3479676, 'spent': 950714, 'cash_on_hand': 4983226, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/babin-brian/summary?cid=N00005736&cycle=2024', 'name': 'Brian Babin', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 1168395, 'spent': 1447131, 'cash_on_hand': 646202, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bacon-donald-john/summary?cid=N00037049&cycle=2024', 'name': 'Donald John Bacon', 'state': 'Nebraska', 'chamber': 'House', 'party': 'Republican', 'raised': 6328059, 'spent': 6143861, 'cash_on_hand': 198433, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/baird-jim/summary?cid=N00041954&cycle=2024', 'name': 'Jim Baird', 'state': 'Indiana', 'chamber': 'House', 'party': 'Republican', 'raised': 455567, 'spent': 581699, 'cash_on_hand': 214609, 'debts': 210000}
# {'link': 'https://www.opensecrets.org/members-of-congress/balderson-troy/summary?cid=N00042194&cycle=2024', 'name': 'Troy Balderson', 'state': 'Ohio', 'chamber': 'House', 'party': 'Republican', 'raised': 2116544, 'spent': 1513911, 'cash_on_hand': 1006424, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/baldwin-tammy/summary?cid=N00004367&cycle=2024', 'name': 'Tammy Baldwin', 'state': 'Wisconsin', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 49272063, 'spent': 52285855, 'cash_on_hand': 25266, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/balint-becca/summary?cid=N00049900&cycle=2024', 'name': 'Becca Balint', 'state': 'Vermont', 'chamber': 'House', 'party': 'Democrat', 'raised': 1372633, 'spent': 1258428, 'cash_on_hand': 145761, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/banks-jim/summary?cid=N00037185&cycle=2024', 'name': 'Jim Banks', 'state': 'Indiana', 'chamber': 'House', 'party': 'Republican', 'raised': 7151158, 'spent': 5873285, 'cash_on_hand': 2613356, 'debts': 151180}
# {'link': 'https://www.opensecrets.org/members-of-congress/barr-andy/summary?cid=N00031233&cycle=2024', 'name': 'Andy Barr', 'state': 'Kentucky', 'chamber': 'House', 'party': 'Republican', 'raised': 4940959, 'spent': 3288653, 'cash_on_hand': 3693077, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/barragan-nanette/summary?cid=N00037019&cycle=2024', 'name': 'Nanette Barragan', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1247135, 'spent': 1269352, 'cash_on_hand': 1481553, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/barrasso-john/summary?cid=N00006236&cycle=2024', 'name': 'John Barrasso', 'state': 'Wyoming', 'chamber': 'Senate', 'party': 'Republican', 'raised': 7710448, 'spent': 4469596, 'cash_on_hand': 7728428, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bean-aaron/summary?cid=N00051369&cycle=2024', 'name': 'Aaron Bean', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 1729435, 'spent': 1347579, 'cash_on_hand': 474720, 'debts': 1610}
# {'link': 'https://www.opensecrets.org/members-of-congress/beatty-joyce/summary?cid=N00033904&cycle=2024', 'name': 'Joyce Beatty', 'state': 'Ohio', 'chamber': 'House', 'party': 'Democrat', 'raised': 1810215, 'spent': 1255125, 'cash_on_hand': 2712573, 'debts': 2500}
# {'link': 'https://www.opensecrets.org/members-of-congress/bennet-michael/summary?cid=N00030608&cycle=2024', 'name': 'Michael Bennet', 'state': 'Colorado', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 1038360, 'spent': 1312297, 'cash_on_hand': 466855, 'debts': 374819}
# {'link': 'https://www.opensecrets.org/members-of-congress/bentz-cliff/summary?cid=N00045773&cycle=2024', 'name': 'Cliff Bentz', 'state': 'Oregon', 'chamber': 'House', 'party': 'Republican', 'raised': 1093067, 'spent': 708637, 'cash_on_hand': 1056344, 'debts': 48100}
# {'link': 'https://www.opensecrets.org/members-of-congress/bera-ami/summary?cid=N00030717&cycle=2024', 'name': 'Ami Bera', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1114105, 'spent': 975867, 'cash_on_hand': 1873371, 'debts': 57800}
# {'link': 'https://www.opensecrets.org/members-of-congress/bergman-john/summary?cid=N00039533&cycle=2024', 'name': 'John Bergman', 'state': 'Michigan', 'chamber': 'House', 'party': 'Republican', 'raised': 1948888, 'spent': 1848010, 'cash_on_hand': 110949, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/beyer-don/summary?cid=N00036018&cycle=2024', 'name': 'Don Beyer', 'state': 'Virginia', 'chamber': 'House', 'party': 'Democrat', 'raised': 1924971, 'spent': 1964672, 'cash_on_hand': 557062, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bice-stephanie/summary?cid=N00044579&cycle=2024', 'name': 'Stephanie Bice', 'state': 'Oklahoma', 'chamber': 'House', 'party': 'Republican', 'raised': 2096812, 'spent': 1632477, 'cash_on_hand': 1085948, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/biggs-andy/summary?cid=N00039293&cycle=2024', 'name': 'Andy Biggs', 'state': 'Arizona', 'chamber': 'House', 'party': 'Republican', 'raised': 1354408, 'spent': 1131002, 'cash_on_hand': 458877, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bilirakis-gus/summary?cid=N00027462&cycle=2024', 'name': 'Gus Bilirakis', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 1750412, 'spent': 1772092, 'cash_on_hand': 121417, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bishop-dan/summary?cid=N00044335&cycle=2024', 'name': 'Dan Bishop', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 223950, 'spent': 1487070, 'cash_on_hand': 37108, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bishop-sanford/summary?cid=N00002674&cycle=2024', 'name': 'Sanford Bishop', 'state': 'Georgia', 'chamber': 'House', 'party': 'Democrat', 'raised': 1890476, 'spent': 1761832, 'cash_on_hand': 182860, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/blackburn-marsha/summary?cid=N00003105&cycle=2024', 'name': 'Marsha Blackburn', 'state': 'Tennessee', 'chamber': 'Senate', 'party': 'Republican', 'raised': 13491615, 'spent': 11980087, 'cash_on_hand': 5138614, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/blumenauer-earl/summary?cid=N00007727&cycle=2024', 'name': 'Earl Blumenauer', 'state': 'Oregon', 'chamber': 'House', 'party': 'Democrat', 'raised': 1030087, 'spent': 806833, 'cash_on_hand': 995025, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/blumenthal-richard/summary?cid=N00031685&cycle=2024', 'name': 'Richard Blumenthal', 'state': 'Connecticut', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 369837, 'spent': 381584, 'cash_on_hand': 1238141, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/boebert-lauren/summary?cid=N00045974&cycle=2024', 'name': 'Lauren Boebert', 'state': 'Colorado', 'chamber': 'House', 'party': 'Republican', 'raised': 4730531, 'spent': 5342661, 'cash_on_hand': 159145, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bonamici-suzanne/summary?cid=N00033474&cycle=2024', 'name': 'Suzanne Bonamici', 'state': 'Oregon', 'chamber': 'House', 'party': 'Democrat', 'raised': 933462, 'spent': 1013259, 'cash_on_hand': 545964, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/booker-cory/summary?cid=N00035267&cycle=2024', 'name': 'Cory Booker', 'state': 'New Jersey', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 7838452, 'spent': 4556572, 'cash_on_hand': 11192485, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/boozman-john/summary?cid=N00013873&cycle=2024', 'name': 'John Boozman', 'state': 'Arkansas', 'chamber': 'Senate', 'party': 'Republican', 'raised': 725759, 'spent': 507202, 'cash_on_hand': 1110776, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bost-mike/summary?cid=N00035420&cycle=2024', 'name': 'Mike Bost', 'state': 'Illinois', 'chamber': 'House', 'party': 'Republican', 'raised': 3092672, 'spent': 3130247, 'cash_on_hand': 352296, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bowman-jamaal/summary?cid=N00044790&cycle=2024', 'name': 'Jamaal Bowman', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 5626499, 'spent': 5568131, 'cash_on_hand': 79884, 'debts': 13261}
# {'link': 'https://www.opensecrets.org/members-of-congress/boyle-brendan/summary?cid=N00035307&cycle=2024', 'name': 'Brendan Boyle', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 2328291, 'spent': 834948, 'cash_on_hand': 3838283, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/braun-mike/summary?cid=N00041731&cycle=2024', 'name': 'Mike Braun', 'state': 'Indiana', 'chamber': 'Senate', 'party': 'Republican', 'raised': -94960, 'spent': 260452, 'cash_on_hand': -1991, 'debts': 486069}
# {'link': 'https://www.opensecrets.org/members-of-congress/brecheen-josh/summary?cid=N00051106&cycle=2024', 'name': 'Josh Brecheen', 'state': 'Oklahoma', 'chamber': 'House', 'party': 'Republican', 'raised': 331851, 'spent': 334994, 'cash_on_hand': 70695, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/britt-katie-boyd/summary?cid=N00048812&cycle=2024', 'name': 'Katie Boyd Britt', 'state': 'Alabama', 'chamber': 'Senate', 'party': 'Republican', 'raised': 3895655, 'spent': 1494837, 'cash_on_hand': 4109548, 'debts': 30327}
# {'link': 'https://www.opensecrets.org/members-of-congress/brown-sherrod/summary?cid=N00003535&cycle=2024', 'name': 'Sherrod Brown', 'state': 'Ohio', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 93695161, 'spent': 96729563, 'cash_on_hand': 394230, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/brown-shontel/summary?cid=N00047875&cycle=2024', 'name': 'Shontel Brown', 'state': 'Ohio', 'chamber': 'House', 'party': 'Democrat', 'raised': 1396912, 'spent': 904921, 'cash_on_hand': 855814, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/brownley-julia/summary?cid=N00034254&cycle=2024', 'name': 'Julia Brownley', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1581880, 'spent': 988715, 'cash_on_hand': 942357, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/buchanan-vernon/summary?cid=N00027626&cycle=2024', 'name': 'Vernon Buchanan', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 1821782, 'spent': 2155919, 'cash_on_hand': 1049213, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bucshon-larry/summary?cid=N00031227&cycle=2024', 'name': 'Larry Bucshon', 'state': 'Indiana', 'chamber': 'House', 'party': 'Republican', 'raised': 675577, 'spent': 837155, 'cash_on_hand': 315678, 'debts': 26240}
# {'link': 'https://www.opensecrets.org/members-of-congress/budd-ted/summary?cid=N00039551&cycle=2024', 'name': 'Ted Budd', 'state': 'North Carolina', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2009575, 'spent': 1999404, 'cash_on_hand': 282358, 'debts': 75000}
# {'link': 'https://www.opensecrets.org/members-of-congress/budzinski-nikki/summary?cid=N00049102&cycle=2024', 'name': 'Nikki Budzinski', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 4276994, 'spent': 2534004, 'cash_on_hand': 1784732, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/burchett-tim/summary?cid=N00041594&cycle=2024', 'name': 'Tim Burchett', 'state': 'Tennessee', 'chamber': 'House', 'party': 'Republican', 'raised': 1229828, 'spent': 1327896, 'cash_on_hand': 728190, 'debts': 1451}
# {'link': 'https://www.opensecrets.org/members-of-congress/burgess-michael/summary?cid=N00025219&cycle=2024', 'name': 'Michael Burgess', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 1200021, 'spent': 1375791, 'cash_on_hand': 13854, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/burlison-eric/summary?cid=N00049123&cycle=2024', 'name': 'Eric Burlison', 'state': 'Missouri', 'chamber': 'House', 'party': 'Republican', 'raised': 923026, 'spent': 503233, 'cash_on_hand': 601387, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/bush-cori/summary?cid=N00039373&cycle=2024', 'name': 'Cori Bush', 'state': 'Missouri', 'chamber': 'House', 'party': 'Democrat', 'raised': 3931524, 'spent': 3920038, 'cash_on_hand': 22333, 'debts': 1259}
# {'link': 'https://www.opensecrets.org/members-of-congress/butler-laphonza-r/summary?cid=N00054689&cycle=2024', 'name': 'Laphonza R Butler', 'state': 'California', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 0, 'spent': 0, 'cash_on_hand': 0, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/calvert-ken/summary?cid=N00007099&cycle=2024', 'name': 'Ken Calvert', 'state': 'California', 'chamber': 'House', 'party': 'Republican', 'raised': 8016040, 'spent': 7823706, 'cash_on_hand': 262135, 'debts': 15464}
# {'link': 'https://www.opensecrets.org/members-of-congress/cammack-kat/summary?cid=N00045978&cycle=2024', 'name': 'Kat Cammack', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 2634508, 'spent': 2118359, 'cash_on_hand': 555550, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cantwell-maria/summary?cid=N00007836&cycle=2024', 'name': 'Maria Cantwell', 'state': 'Washington', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 10959410, 'spent': 10537830, 'cash_on_hand': 611211, 'debts': 2173182}
# {'link': 'https://www.opensecrets.org/members-of-congress/capito-shelley-moore/summary?cid=N00009771&cycle=2024', 'name': 'Shelley Moore Capito', 'state': 'West Virginia', 'chamber': 'Senate', 'party': 'Republican', 'raised': 1001825, 'spent': 1529244, 'cash_on_hand': 2311365, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/caraveo-yadira/summary?cid=N00049068&cycle=2024', 'name': 'Yadira Caraveo', 'state': 'Colorado', 'chamber': 'House', 'party': 'Democrat', 'raised': 8048642, 'spent': 8061839, 'cash_on_hand': 4345, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carbajal-salud/summary?cid=N00037015&cycle=2024', 'name': 'Salud Carbajal', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 2014462, 'spent': 1474579, 'cash_on_hand': 2643869, 'debts': 1945}
# {'link': 'https://www.opensecrets.org/members-of-congress/cardenas-tony/summary?cid=N00033373&cycle=2024', 'name': 'Tony Cardenas', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 591968, 'spent': 785330, 'cash_on_hand': 45909, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cardin-ben/summary?cid=N00001955&cycle=2024', 'name': 'Ben Cardin', 'state': 'Maryland', 'chamber': 'Senate', 'party': 'Democrat', 'raised': -23439, 'spent': 531406, 'cash_on_hand': 463441, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carey-mike/summary?cid=N00048568&cycle=2024', 'name': 'Mike Carey', 'state': 'Ohio', 'chamber': 'House', 'party': 'Republican', 'raised': 2644015, 'spent': 2561337, 'cash_on_hand': 161294, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carl-jerry/summary?cid=N00044245&cycle=2024', 'name': 'Jerry Carl', 'state': 'Alabama', 'chamber': 'House', 'party': 'Republican', 'raised': 1791145, 'spent': 2175752, 'cash_on_hand': 69290, 'debts': 254535}
# {'link': 'https://www.opensecrets.org/members-of-congress/carper-tom/summary?cid=N00012508&cycle=2024', 'name': 'Tom Carper', 'state': 'Delaware', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 12630, 'spent': 511925, 'cash_on_hand': 55789, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carson-andre/summary?cid=N00029513&cycle=2024', 'name': 'Andre Carson', 'state': 'Indiana', 'chamber': 'House', 'party': 'Democrat', 'raised': 820448, 'spent': 1082126, 'cash_on_hand': 449423, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carter-buddy/summary?cid=N00035346&cycle=2024', 'name': 'Buddy Carter', 'state': 'Georgia', 'chamber': 'House', 'party': 'Republican', 'raised': 2581502, 'spent': 1380180, 'cash_on_hand': 3018930, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carter-john/summary?cid=N00025095&cycle=2024', 'name': 'John Carter', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 1199482, 'spent': 1569535, 'cash_on_hand': 41438, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/carter-troy/summary?cid=N00025766&cycle=2024', 'name': 'Troy Carter', 'state': 'Louisiana', 'chamber': 'House', 'party': 'Democrat', 'raised': 1998420, 'spent': 1855198, 'cash_on_hand': 509409, 'debts': 24914}
# {'link': 'https://www.opensecrets.org/members-of-congress/cartwright-matt/summary?cid=N00034128&cycle=2024', 'name': 'Matt Cartwright', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 8563883, 'spent': 8527729, 'cash_on_hand': 88774, 'debts': 242800}
# {'link': 'https://www.opensecrets.org/members-of-congress/casar-greg/summary?cid=N00049855&cycle=2024', 'name': 'Greg Casar', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 1108368, 'spent': 900490, 'cash_on_hand': 370838, 'debts': 10000}
# {'link': 'https://www.opensecrets.org/members-of-congress/case-ed/summary?cid=N00025882&cycle=2024', 'name': 'Ed Case', 'state': 'Hawaii', 'chamber': 'House', 'party': 'Democrat', 'raised': 699439, 'spent': 890311, 'cash_on_hand': 316658, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/casey-bob/summary?cid=N00027503&cycle=2024', 'name': 'Bob Casey', 'state': 'Pennsylvania', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 57106238, 'spent': 59193080, 'cash_on_hand': 995039, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cassidy-bill/summary?cid=N00030245&cycle=2024', 'name': 'Bill Cassidy', 'state': 'Louisiana', 'chamber': 'Senate', 'party': 'Republican', 'raised': 4021963, 'spent': 642654, 'cash_on_hand': 6580418, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/casten-sean/summary?cid=N00041338&cycle=2024', 'name': 'Sean Casten', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 3007318, 'spent': 2367592, 'cash_on_hand': 694142, 'debts': 75694}
# {'link': 'https://www.opensecrets.org/members-of-congress/castor-kathy/summary?cid=N00027514&cycle=2024', 'name': 'Kathy Castor', 'state': 'Florida', 'chamber': 'House', 'party': 'Democrat', 'raised': 1162514, 'spent': 1286754, 'cash_on_hand': 226729, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/castro-joaquin/summary?cid=N00033316&cycle=2024', 'name': 'Joaquin Castro', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 677235, 'spent': 701322, 'cash_on_hand': 138657, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/chavez-deremer-lori/summary?cid=N00048900&cycle=2024', 'name': 'Lori Chavez-Deremer', 'state': 'Oregon', 'chamber': 'House', 'party': 'Republican', 'raised': 5962097, 'spent': 5618224, 'cash_on_hand': 353333, 'debts': 303477}
# {'link': 'https://www.opensecrets.org/members-of-congress/cherfilus-mccormick-sheila/summary?cid=N00043504&cycle=2024', 'name': 'Sheila Cherfilus-McCormick', 'state': 'Florida', 'chamber': 'House', 'party': 'Democrat', 'raised': 491757, 'spent': 487019, 'cash_on_hand': 7516, 'debts': 4187691}
# {'link': 'https://www.opensecrets.org/members-of-congress/chu-judy/summary?cid=N00030600&cycle=2024', 'name': 'Judy Chu', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1894637, 'spent': 1640024, 'cash_on_hand': 3602004, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/ciscomani-juan/summary?cid=N00049039&cycle=2024', 'name': 'Juan Ciscomani', 'state': 'Arizona', 'chamber': 'House', 'party': 'Republican', 'raised': 6876504, 'spent': 6694379, 'cash_on_hand': 236560, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/clark-katherine/summary?cid=N00035278&cycle=2024', 'name': 'Katherine Clark', 'state': 'Massachusetts', 'chamber': 'House', 'party': 'Democrat', 'raised': 4850378, 'spent': 4631637, 'cash_on_hand': 1325890, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/clarke-yvette/summary?cid=N00026961&cycle=2024', 'name': 'Yvette Clarke', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 1095515, 'spent': 1048165, 'cash_on_hand': 110054, 'debts': 49480}
# {'link': 'https://www.opensecrets.org/members-of-congress/cleaver-emanuel/summary?cid=N00026790&cycle=2024', 'name': 'Emanuel Cleaver', 'state': 'Missouri', 'chamber': 'House', 'party': 'Democrat', 'raised': 1384775, 'spent': 1456206, 'cash_on_hand': 889626, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cline-ben/summary?cid=N00042296&cycle=2024', 'name': 'Ben Cline', 'state': 'Virginia', 'chamber': 'House', 'party': 'Republican', 'raised': 1012181, 'spent': 951199, 'cash_on_hand': 328322, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cloud-michael/summary?cid=N00041882&cycle=2024', 'name': 'Michael Cloud', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 785113, 'spent': 929722, 'cash_on_hand': 136877, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/clyburn-james-e/summary?cid=N00002408&cycle=2024', 'name': 'James E Clyburn', 'state': 'South Carolina', 'chamber': 'House', 'party': 'Democrat', 'raised': 2219818, 'spent': 2675227, 'cash_on_hand': 1839127, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/clyde-andrew/summary?cid=N00046654&cycle=2024', 'name': 'Andrew Clyde', 'state': 'Georgia', 'chamber': 'House', 'party': 'Republican', 'raised': 561936, 'spent': 490757, 'cash_on_hand': 95984, 'debts': 1308863}
# {'link': 'https://www.opensecrets.org/members-of-congress/cohen-steve/summary?cid=N00003225&cycle=2024', 'name': 'Steve Cohen', 'state': 'Tennessee', 'chamber': 'House', 'party': 'Democrat', 'raised': 657841, 'spent': 456622, 'cash_on_hand': 1648597, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cole-tom/summary?cid=N00025726&cycle=2024', 'name': 'Tom Cole', 'state': 'Oklahoma', 'chamber': 'House', 'party': 'Republican', 'raised': 5570715, 'spent': 5005357, 'cash_on_hand': 1780273, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/coleman-bonnie-watson/summary?cid=N00036158&cycle=2024', 'name': 'Bonnie Watson Coleman', 'state': 'New Jersey', 'chamber': 'House', 'party': 'Democrat', 'raised': 929386, 'spent': 958650, 'cash_on_hand': 39378, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/collins-mike/summary?cid=N00035370&cycle=2024', 'name': 'Mike Collins', 'state': 'Georgia', 'chamber': 'House', 'party': 'Republican', 'raised': 1704745, 'spent': 1304622, 'cash_on_hand': 597195, 'debts': 286941}
# {'link': 'https://www.opensecrets.org/members-of-congress/collins-susan-m/summary?cid=N00000491&cycle=2024', 'name': 'Susan M Collins', 'state': 'Maine', 'chamber': 'Senate', 'party': 'Republican', 'raised': 1619601, 'spent': 640710, 'cash_on_hand': 2576308, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/comer-james/summary?cid=N00038260&cycle=2024', 'name': 'James Comer', 'state': 'Kentucky', 'chamber': 'House', 'party': 'Republican', 'raised': 7596324, 'spent': 5464924, 'cash_on_hand': 3209222, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/connolly-gerry/summary?cid=N00029891&cycle=2024', 'name': 'Gerry Connolly', 'state': 'Virginia', 'chamber': 'House', 'party': 'Democrat', 'raised': 2517838, 'spent': 2170076, 'cash_on_hand': 3500260, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/coons-chris/summary?cid=N00031820&cycle=2024', 'name': 'Chris Coons', 'state': 'Delaware', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 1744351, 'spent': 1380254, 'cash_on_hand': 2185199, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cornyn-john/summary?cid=N00024852&cycle=2024', 'name': 'John Cornyn', 'state': 'Texas', 'chamber': 'Senate', 'party': 'Republican', 'raised': 3355600, 'spent': 829198, 'cash_on_hand': 4122282, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/correa-lou/summary?cid=N00037260&cycle=2024', 'name': 'Lou Correa', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1374209, 'spent': 1029489, 'cash_on_hand': 1867362, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/costa-jim/summary?cid=N00026341&cycle=2024', 'name': 'Jim Costa', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1680777, 'spent': 1860974, 'cash_on_hand': 208882, 'debts': 27665}
# {'link': 'https://www.opensecrets.org/members-of-congress/cotton-tom/summary?cid=N00033363&cycle=2024', 'name': 'Tom Cotton', 'state': 'Arkansas', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2476367, 'spent': 2809396, 'cash_on_hand': 7450869, 'debts': 73959}
# {'link': 'https://www.opensecrets.org/members-of-congress/courtney-joe/summary?cid=N00024842&cycle=2024', 'name': 'Joe Courtney', 'state': 'Connecticut', 'chamber': 'House', 'party': 'Democrat', 'raised': 1265676, 'spent': 1086671, 'cash_on_hand': 351111, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/craig-angie/summary?cid=N00037039&cycle=2024', 'name': 'Angie Craig', 'state': 'Minnesota', 'chamber': 'House', 'party': 'Democrat', 'raised': 7785520, 'spent': 7792844, 'cash_on_hand': 23602, 'debts': 373000}
# {'link': 'https://www.opensecrets.org/members-of-congress/cramer-kevin/summary?cid=N00004614&cycle=2024', 'name': 'Kevin Cramer', 'state': 'North Dakota', 'chamber': 'Senate', 'party': 'Republican', 'raised': 5399686, 'spent': 3451337, 'cash_on_hand': 2354889, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/crane-eli/summary?cid=N00048953&cycle=2024', 'name': 'Eli Crane', 'state': 'Arizona', 'chamber': 'House', 'party': 'Republican', 'raised': 8437396, 'spent': 8186282, 'cash_on_hand': 317370, 'debts': 202776}
# {'link': 'https://www.opensecrets.org/members-of-congress/crapo-mike/summary?cid=N00006267&cycle=2024', 'name': 'Mike Crapo', 'state': 'Idaho', 'chamber': 'Senate', 'party': 'Republican', 'raised': 1039773, 'spent': 854547, 'cash_on_hand': 2571593, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/crawford-rick/summary?cid=N00030770&cycle=2024', 'name': 'Rick Crawford', 'state': 'Arkansas', 'chamber': 'House', 'party': 'Republican', 'raised': 1097029, 'spent': 888704, 'cash_on_hand': 830826, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/crenshaw-dan/summary?cid=N00042224&cycle=2024', 'name': 'Dan Crenshaw', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 4056322, 'spent': 4724458, 'cash_on_hand': 469307, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/crockett-jasmine/summary?cid=N00049840&cycle=2024', 'name': 'Jasmine Crockett', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 3036171, 'spent': 1577787, 'cash_on_hand': 1611233, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/crow-jason/summary?cid=N00040876&cycle=2024', 'name': 'Jason Crow', 'state': 'Colorado', 'chamber': 'House', 'party': 'Democrat', 'raised': 2182038, 'spent': 2015030, 'cash_on_hand': 1748293, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cruz-ted/summary?cid=N00033085&cycle=2024', 'name': 'Ted Cruz', 'state': 'Texas', 'chamber': 'Senate', 'party': 'Republican', 'raised': 73627316, 'spent': 75220890, 'cash_on_hand': 1786707, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/cuellar-henry/summary?cid=N00024978&cycle=2024', 'name': 'Henry Cuellar', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 2438318, 'spent': 2435184, 'cash_on_hand': 47958, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/curtis-john/summary?cid=N00041221&cycle=2024', 'name': 'John Curtis', 'state': 'Utah', 'chamber': 'House', 'party': 'Republican', 'raised': 5632554, 'spent': 5230711, 'cash_on_hand': 788682, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/d-esposito-anthony/summary?cid=N00050681&cycle=2024', 'name': "Anthony D'Esposito", 'state': 'New York', 'chamber': 'House', 'party': 'Republican', 'raised': 4519185, 'spent': 4495480, 'cash_on_hand': 46171, 'debts': 25728}
# {'link': 'https://www.opensecrets.org/members-of-congress/daines-steven/summary?cid=N00033054&cycle=2024', 'name': 'Steven Daines', 'state': 'Montana', 'chamber': 'Senate', 'party': 'Republican', 'raised': 1665393, 'spent': 652234, 'cash_on_hand': 1758242, 'debts': 44813}
# {'link': 'https://www.opensecrets.org/members-of-congress/davids-sharice/summary?cid=N00042626&cycle=2024', 'name': 'Sharice Davids', 'state': 'Kansas', 'chamber': 'House', 'party': 'Democrat', 'raised': 5915700, 'spent': 5576068, 'cash_on_hand': 403255, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/davidson-warren/summary?cid=N00038767&cycle=2024', 'name': 'Warren Davidson', 'state': 'Ohio', 'chamber': 'House', 'party': 'Republican', 'raised': 1119756, 'spent': 1062522, 'cash_on_hand': 394701, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/davis-danny-k/summary?cid=N00004884&cycle=2024', 'name': 'Danny K Davis', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 818234, 'spent': 933143, 'cash_on_hand': 105728, 'debts': 66454}
# {'link': 'https://www.opensecrets.org/members-of-congress/davis-don/summary?cid=N00049636&cycle=2024', 'name': 'Don Davis', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Democrat', 'raised': 5997021, 'spent': 5744153, 'cash_on_hand': 270841, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/de-la-cruz-monica/summary?cid=N00045793&cycle=2024', 'name': 'Monica De La Cruz', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 7884300, 'spent': 7322546, 'cash_on_hand': 613969, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/dean-madeleine/summary?cid=N00042894&cycle=2024', 'name': 'Madeleine Dean', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 1739284, 'spent': 1475438, 'cash_on_hand': 968741, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/degette-diana/summary?cid=N00006134&cycle=2024', 'name': 'Diana DeGette', 'state': 'Colorado', 'chamber': 'House', 'party': 'Democrat', 'raised': 1090985, 'spent': 1170356, 'cash_on_hand': 269469, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/delauro-rosa/summary?cid=N00000615&cycle=2024', 'name': 'Rosa DeLauro', 'state': 'Connecticut', 'chamber': 'House', 'party': 'Democrat', 'raised': 1717839, 'spent': 1605846, 'cash_on_hand': 225448, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/delbene-suzan/summary?cid=N00030693&cycle=2024', 'name': 'Suzan DelBene', 'state': 'Washington', 'chamber': 'House', 'party': 'Democrat', 'raised': 3820057, 'spent': 3435881, 'cash_on_hand': 1063720, 'debts': 495000}
# {'link': 'https://www.opensecrets.org/members-of-congress/deluzio-christopher/summary?cid=N00049160&cycle=2024', 'name': 'Christopher Deluzio', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 5017315, 'spent': 4685771, 'cash_on_hand': 353671, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/desaulnier-mark/summary?cid=N00030709&cycle=2024', 'name': 'Mark Desaulnier', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 658948, 'spent': 605325, 'cash_on_hand': 628987, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/desjarlais-scott/summary?cid=N00030957&cycle=2024', 'name': 'Scott Desjarlais', 'state': 'Tennessee', 'chamber': 'House', 'party': 'Republican', 'raised': 305704, 'spent': 255749, 'cash_on_hand': 366018, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/diaz-balart-mario/summary?cid=N00025337&cycle=2024', 'name': 'Mario Diaz-Balart', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 2358125, 'spent': 1818315, 'cash_on_hand': 1819320, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/dingell-debbie/summary?cid=N00036149&cycle=2024', 'name': 'Debbie Dingell', 'state': 'Michigan', 'chamber': 'House', 'party': 'Democrat', 'raised': 1600134, 'spent': 1655017, 'cash_on_hand': 342922, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/doggett-lloyd/summary?cid=N00006023&cycle=2024', 'name': 'Lloyd Doggett', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 1541264, 'spent': 625726, 'cash_on_hand': 6227828, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/donalds-byron/summary?cid=N00034016&cycle=2024', 'name': 'Byron Donalds', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 6563388, 'spent': 5561369, 'cash_on_hand': 1740010, 'debts': 5258}
# {'link': 'https://www.opensecrets.org/members-of-congress/duarte-john/summary?cid=N00050562&cycle=2024', 'name': 'John Duarte', 'state': 'California', 'chamber': 'House', 'party': 'Republican', 'raised': 4522961, 'spent': 4333721, 'cash_on_hand': 214758, 'debts': 119346}
# {'link': 'https://www.opensecrets.org/members-of-congress/duckworth-tammy/summary?cid=N00027860&cycle=2024', 'name': 'Tammy Duckworth', 'state': 'Illinois', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 4515498, 'spent': 3354367, 'cash_on_hand': 2743952, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/duncan-jeff/summary?cid=N00030752&cycle=2024', 'name': 'Jeff Duncan', 'state': 'South Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 784969, 'spent': 836927, 'cash_on_hand': 657719, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/dunn-neal/summary?cid=N00037442&cycle=2024', 'name': 'Neal Dunn', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 1062452, 'spent': 1218001, 'cash_on_hand': 89457, 'debts': 661}
# {'link': 'https://www.opensecrets.org/members-of-congress/durbin-dick/summary?cid=N00004981&cycle=2024', 'name': 'Dick Durbin', 'state': 'Illinois', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 1098132, 'spent': 907085, 'cash_on_hand': 1674787, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/edwards-chuck/summary?cid=N00049670&cycle=2024', 'name': 'Chuck Edwards', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 1211361, 'spent': 1200490, 'cash_on_hand': 108764, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/ellzey-jake/summary?cid=N00042243&cycle=2024', 'name': 'Jake Ellzey', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 6480005, 'spent': 5982232, 'cash_on_hand': 1095447, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/emmer-tom/summary?cid=N00035440&cycle=2024', 'name': 'Tom Emmer', 'state': 'Minnesota', 'chamber': 'House', 'party': 'Republican', 'raised': 8166673, 'spent': 7123848, 'cash_on_hand': 1688451, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/ernst-joni/summary?cid=N00035483&cycle=2024', 'name': 'Joni Ernst', 'state': 'Iowa', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2921362, 'spent': 1655255, 'cash_on_hand': 2239842, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/escobar-veronica/summary?cid=N00041702&cycle=2024', 'name': 'Veronica Escobar', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 1331009, 'spent': 1461877, 'cash_on_hand': 115844, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/eshoo-anna/summary?cid=N00007335&cycle=2024', 'name': 'Anna Eshoo', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 534701, 'spent': 968952, 'cash_on_hand': 86697, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/espaillat-adriano/summary?cid=N00034549&cycle=2024', 'name': 'Adriano Espaillat', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 1358380, 'spent': 1060530, 'cash_on_hand': 396590, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/estes-ron/summary?cid=N00040712&cycle=2024', 'name': 'Ron Estes', 'state': 'Kansas', 'chamber': 'House', 'party': 'Republican', 'raised': 2261594, 'spent': 2006891, 'cash_on_hand': 1198276, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/evans-dwight/summary?cid=N00038450&cycle=2024', 'name': 'Dwight Evans', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 975610, 'spent': 1033088, 'cash_on_hand': 76137, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/ezell-mike/summary?cid=N00048240&cycle=2024', 'name': 'Mike Ezell', 'state': 'Mississippi', 'chamber': 'House', 'party': 'Republican', 'raised': 1214459, 'spent': 1071266, 'cash_on_hand': 151465, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fallon-patrick/summary?cid=N00047264&cycle=2024', 'name': 'Patrick Fallon', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 746315, 'spent': 343826, 'cash_on_hand': 660078, 'debts': 25000}
# {'link': 'https://www.opensecrets.org/members-of-congress/feenstra-randy/summary?cid=N00044011&cycle=2024', 'name': 'Randy Feenstra', 'state': 'Iowa', 'chamber': 'House', 'party': 'Republican', 'raised': 4242569, 'spent': 4095863, 'cash_on_hand': 1170394, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/ferguson-drew/summary?cid=N00039090&cycle=2024', 'name': 'Drew Ferguson', 'state': 'Georgia', 'chamber': 'House', 'party': 'Republican', 'raised': 818067, 'spent': 1177624, 'cash_on_hand': 58752, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fernandez-teresa-leger/summary?cid=N00044559&cycle=2024', 'name': 'Teresa Leger Fernandez', 'state': 'New Mexico', 'chamber': 'House', 'party': 'Democrat', 'raised': 2105098, 'spent': 1730000, 'cash_on_hand': 407925, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fetterman-john/summary?cid=N00038201&cycle=2024', 'name': 'John Fetterman', 'state': 'Pennsylvania', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 7081989, 'spent': 5394652, 'cash_on_hand': 2314686, 'debts': 5034}
# {'link': 'https://www.opensecrets.org/members-of-congress/finstad-brad/summary?cid=N00050649&cycle=2024', 'name': 'Brad Finstad', 'state': 'Minnesota', 'chamber': 'House', 'party': 'Republican', 'raised': 1954782, 'spent': 1893637, 'cash_on_hand': 61409, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fischbach-michelle/summary?cid=N00045251&cycle=2024', 'name': 'Michelle Fischbach', 'state': 'Minnesota', 'chamber': 'House', 'party': 'Republican', 'raised': 2010301, 'spent': 1610225, 'cash_on_hand': 411080, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fischer-deb/summary?cid=N00033443&cycle=2024', 'name': 'Deb Fischer', 'state': 'Nebraska', 'chamber': 'Senate', 'party': 'Republican', 'raised': 6282643, 'spent': 7657628, 'cash_on_hand': 25211, 'debts': 95547}
# {'link': 'https://www.opensecrets.org/members-of-congress/fitzgerald-scott/summary?cid=N00045434&cycle=2024', 'name': 'Scott Fitzgerald', 'state': 'Wisconsin', 'chamber': 'House', 'party': 'Republican', 'raised': 1308310, 'spent': 864904, 'cash_on_hand': 836235, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fitzpatrick-brian/summary?cid=N00038779&cycle=2024', 'name': 'Brian Fitzpatrick', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Republican', 'raised': 6307839, 'spent': 3345223, 'cash_on_hand': 4422529, 'debts': 24750}
# {'link': 'https://www.opensecrets.org/members-of-congress/fleischmann-chuck/summary?cid=N00030815&cycle=2024', 'name': 'Chuck Fleischmann', 'state': 'Tennessee', 'chamber': 'House', 'party': 'Republican', 'raised': 1889739, 'spent': 646208, 'cash_on_hand': 3257052, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fletcher-lizzie/summary?cid=N00041194&cycle=2024', 'name': 'Lizzie Fletcher', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 2412593, 'spent': 2417638, 'cash_on_hand': 1316661, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/flood-mike/summary?cid=N00050145&cycle=2024', 'name': 'Mike Flood', 'state': 'Nebraska', 'chamber': 'House', 'party': 'Republican', 'raised': 2005390, 'spent': 1791480, 'cash_on_hand': 220781, 'debts': 102053}
# {'link': 'https://www.opensecrets.org/members-of-congress/fong-vince/summary?cid=N00054216&cycle=2024', 'name': 'Vince Fong', 'state': 'California', 'chamber': 'House', 'party': 'Republican', 'raised': 2306086, 'spent': 2266855, 'cash_on_hand': 39231, 'debts': 147126}
# {'link': 'https://www.opensecrets.org/members-of-congress/foster-bill/summary?cid=N00029139&cycle=2024', 'name': 'Bill Foster', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 3218842, 'spent': 2473392, 'cash_on_hand': 1550564, 'debts': 1017994}
# {'link': 'https://www.opensecrets.org/members-of-congress/foushee-valerie/summary?cid=N00049652&cycle=2024', 'name': 'Valerie Foushee', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Democrat', 'raised': 683925, 'spent': 725941, 'cash_on_hand': 85695, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/foxx-virginia/summary?cid=N00026166&cycle=2024', 'name': 'Virginia Foxx', 'state': 'North Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 2361024, 'spent': 1962781, 'cash_on_hand': 2911268, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/frankel-lois/summary?cid=N00002893&cycle=2024', 'name': 'Lois Frankel', 'state': 'Florida', 'chamber': 'House', 'party': 'Democrat', 'raised': 1859626, 'spent': 2218012, 'cash_on_hand': 287321, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/franklin-scott/summary?cid=N00046760&cycle=2024', 'name': 'Scott Franklin', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 664056, 'spent': 534936, 'cash_on_hand': 481895, 'debts': 390000}
# {'link': 'https://www.opensecrets.org/members-of-congress/frost-maxwell/summary?cid=N00049075&cycle=2024', 'name': 'Maxwell Frost', 'state': 'Florida', 'chamber': 'House', 'party': 'Democrat', 'raised': 3930459, 'spent': 3172732, 'cash_on_hand': 1091725, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fry-russell/summary?cid=N00049165&cycle=2024', 'name': 'Russell Fry', 'state': 'South Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 1473348, 'spent': 1121904, 'cash_on_hand': 561182, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/fulcher-russ/summary?cid=N00041335&cycle=2024', 'name': 'Russ Fulcher', 'state': 'Idaho', 'chamber': 'House', 'party': 'Republican', 'raised': 626646, 'spent': 615924, 'cash_on_hand': 180008, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/gallagher-mike/summary?cid=N00039330&cycle=2024', 'name': 'Mike Gallagher', 'state': 'Wisconsin', 'chamber': 'House', 'party': 'Republican', 'raised': 0, 'spent': 0, 'cash_on_hand': 0, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/gallego-ruben/summary?cid=N00036097&cycle=2024', 'name': 'Ruben Gallego', 'state': 'Arizona', 'chamber': 'House', 'party': 'Democrat', 'raised': 63777612, 'spent': 64843034, 'cash_on_hand': 211152, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/garamendi-john/summary?cid=N00030856&cycle=2024', 'name': 'John Garamendi', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1093483, 'spent': 950213, 'cash_on_hand': 1264717, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/garbarino-andrew/summary?cid=N00046030&cycle=2024', 'name': 'Andrew Garbarino', 'state': 'New York', 'chamber': 'House', 'party': 'Republican', 'raised': 3760308, 'spent': 2511783, 'cash_on_hand': 1545606, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/garcia-jesus/summary?cid=N00042114&cycle=2024', 'name': 'Jesus Garcia', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 798895, 'spent': 788084, 'cash_on_hand': 35835, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/garcia-mike/summary?cid=N00044298&cycle=2024', 'name': 'Mike Garcia', 'state': 'California', 'chamber': 'House', 'party': 'Republican', 'raised': 6485208, 'spent': 6552023, 'cash_on_hand': 49856, 'debts': 3173}
# {'link': 'https://www.opensecrets.org/members-of-congress/garcia-robert/summary?cid=N00049470&cycle=2024', 'name': 'Robert Garcia', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1326792, 'spent': 1244926, 'cash_on_hand': 412427, 'debts': 27095}
# ...
# {'link': 'https://www.opensecrets.org/members-of-congress/takano-mark/summary?cid=N00006701&cycle=2024', 'name': 'Mark Takano', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1281859, 'spent': 1503895, 'cash_on_hand': 269169, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tenney-claudia/summary?cid=N00036351&cycle=2024', 'name': 'Claudia Tenney', 'state': 'New York', 'chamber': 'House', 'party': 'Republican', 'raised': 2993079, 'spent': 2699526, 'cash_on_hand': 355002, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tester-jon/summary?cid=N00027605&cycle=2024', 'name': 'Jon Tester', 'state': 'Montana', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 91699967, 'spent': 93819102, 'cash_on_hand': 765623, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/thanedar-shri/summary?cid=N00049602&cycle=2024', 'name': 'Shri Thanedar', 'state': 'Michigan', 'chamber': 'House', 'party': 'Democrat', 'raised': 9477462, 'spent': 2690091, 'cash_on_hand': 6904567, 'debts': 11470000}
# {'link': 'https://www.opensecrets.org/members-of-congress/thompson-bennie-g/summary?cid=N00003288&cycle=2024', 'name': 'Bennie G Thompson', 'state': 'Mississippi', 'chamber': 'House', 'party': 'Democrat', 'raised': 1232971, 'spent': 1337716, 'cash_on_hand': 1626164, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/thompson-glenn/summary?cid=N00029736&cycle=2024', 'name': 'Glenn Thompson', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Republican', 'raised': 2819758, 'spent': 2381740, 'cash_on_hand': 791793, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/thompson-mike/summary?cid=N00007419&cycle=2024', 'name': 'Mike Thompson', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 2423433, 'spent': 2841779, 'cash_on_hand': 1209488, 'debts': 36045}
# {'link': 'https://www.opensecrets.org/members-of-congress/thune-john/summary?cid=N00004572&cycle=2024', 'name': 'John Thune', 'state': 'South Dakota', 'chamber': 'Senate', 'party': 'Republican', 'raised': 4139244, 'spent': 5697140, 'cash_on_hand': 15384337, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tiffany-tom/summary?cid=N00045307&cycle=2024', 'name': 'Tom Tiffany', 'state': 'Wisconsin', 'chamber': 'House', 'party': 'Republican', 'raised': 1241428, 'spent': 1405158, 'cash_on_hand': 175940, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tillis-thom/summary?cid=N00035492&cycle=2024', 'name': 'Thom Tillis', 'state': 'North Carolina', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2413956, 'spent': 911088, 'cash_on_hand': 2238086, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/timmons-william/summary?cid=N00042715&cycle=2024', 'name': 'William Timmons', 'state': 'South Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 1329634, 'spent': 1321533, 'cash_on_hand': 20115, 'debts': 309538}
# {'link': 'https://www.opensecrets.org/members-of-congress/titus-dina/summary?cid=N00030191&cycle=2024', 'name': 'Dina Titus', 'state': 'Nevada', 'chamber': 'House', 'party': 'Democrat', 'raised': 2427312, 'spent': 2445151, 'cash_on_hand': 155363, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tlaib-rashida/summary?cid=N00042649&cycle=2024', 'name': 'Rashida Tlaib', 'state': 'Michigan', 'chamber': 'House', 'party': 'Democrat', 'raised': 8361649, 'spent': 4335398, 'cash_on_hand': 4263554, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tokuda-jill/summary?cid=N00051049&cycle=2024', 'name': 'Jill Tokuda', 'state': 'Hawaii', 'chamber': 'House', 'party': 'Democrat', 'raised': 961307, 'spent': 678602, 'cash_on_hand': 483440, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/tonko-paul/summary?cid=N00030196&cycle=2024', 'name': 'Paul Tonko', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 1541764, 'spent': 1668388, 'cash_on_hand': 599501, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/torres-norma/summary?cid=N00036107&cycle=2024', 'name': 'Norma Torres', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 932868, 'spent': 976808, 'cash_on_hand': 303315, 'debts': 300}
# {'link': 'https://www.opensecrets.org/members-of-congress/torres-ritchie/summary?cid=N00044346&cycle=2024', 'name': 'Ritchie Torres', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 9084007, 'spent': 1607575, 'cash_on_hand': 11325834, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/trahan-lori/summary?cid=N00041808&cycle=2024', 'name': 'Lori Trahan', 'state': 'Massachusetts', 'chamber': 'House', 'party': 'Democrat', 'raised': 1717667, 'spent': 1130015, 'cash_on_hand': 1455151, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/trone-david/summary?cid=N00039122&cycle=2024', 'name': 'David Trone', 'state': 'Maryland', 'chamber': 'House', 'party': 'Democrat', 'raised': 63589344, 'spent': 63788609, 'cash_on_hand': 3841, 'debts': 73680994}
# {'link': 'https://www.opensecrets.org/members-of-congress/tuberville-tommy/summary?cid=N00044434&cycle=2024', 'name': 'Tommy Tuberville', 'state': 'Alabama', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2133700, 'spent': 1736780, 'cash_on_hand': 532330, 'debts': 13423}
# {'link': 'https://www.opensecrets.org/members-of-congress/turner-michael-r/summary?cid=N00025175&cycle=2024', 'name': 'Michael R Turner', 'state': 'Ohio', 'chamber': 'House', 'party': 'Republican', 'raised': 1237218, 'spent': 1377661, 'cash_on_hand': 430424, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/underwood-lauren-a/summary?cid=N00041569&cycle=2024', 'name': 'Lauren A Underwood', 'state': 'Illinois', 'chamber': 'House', 'party': 'Democrat', 'raised': 4082518, 'spent': 3814502, 'cash_on_hand': 1055102, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/valadao-david/summary?cid=N00033367&cycle=2024', 'name': 'David Valadao', 'state': 'California', 'chamber': 'House', 'party': 'Republican', 'raised': 4873747, 'spent': 4876650, 'cash_on_hand': 45535, 'debts': 13724}
# {'link': 'https://www.opensecrets.org/members-of-congress/van-drew-jeff/summary?cid=N00042164&cycle=2024', 'name': 'Jeff Van Drew', 'state': 'New Jersey', 'chamber': 'House', 'party': 'Republican', 'raised': 3197984, 'spent': 2914965, 'cash_on_hand': 762430, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/van-duyne-beth/summary?cid=N00045167&cycle=2024', 'name': 'Beth Van Duyne', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 3124044, 'spent': 2262958, 'cash_on_hand': 1960872, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/van-hollen-chris/summary?cid=N00013820&cycle=2024', 'name': 'Chris Van Hollen', 'state': 'Maryland', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 275885, 'spent': 552606, 'cash_on_hand': 1953402, 'debts': 2209}
# {'link': 'https://www.opensecrets.org/members-of-congress/van-orden-derrick/summary?cid=N00046843&cycle=2024', 'name': 'Derrick Van Orden', 'state': 'Wisconsin', 'chamber': 'House', 'party': 'Republican', 'raised': 7458951, 'spent': 7119809, 'cash_on_hand': 516806, 'debts': 92228}
# {'link': 'https://www.opensecrets.org/members-of-congress/vance-j-d/summary?cid=N00048832&cycle=2024', 'name': 'J D Vance', 'state': 'Ohio', 'chamber': 'Senate', 'party': 'Republican', 'raised': 2004452, 'spent': 2310129, 'cash_on_hand': 135631, 'debts': 103207}
# {'link': 'https://www.opensecrets.org/members-of-congress/vargas-juan/summary?cid=N00007021&cycle=2024', 'name': 'Juan Vargas', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 790624, 'spent': 919328, 'cash_on_hand': 90840, 'debts': 1838}
# {'link': 'https://www.opensecrets.org/members-of-congress/vasquez-gabe/summary?cid=N00049142&cycle=2024', 'name': 'Gabe Vasquez', 'state': 'New Mexico', 'chamber': 'House', 'party': 'Democrat', 'raised': 6956819, 'spent': 6940511, 'cash_on_hand': 39085, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/veasey-marc/summary?cid=N00033839&cycle=2024', 'name': 'Marc Veasey', 'state': 'Texas', 'chamber': 'House', 'party': 'Democrat', 'raised': 1863888, 'spent': 1663953, 'cash_on_hand': 1009480, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/velazquez-nydia/summary?cid=N00001102&cycle=2024', 'name': 'Nydia Velazquez', 'state': 'New York', 'chamber': 'House', 'party': 'Democrat', 'raised': 464287, 'spent': 607971, 'cash_on_hand': 159566, 'debts': 7736}
# {'link': 'https://www.opensecrets.org/members-of-congress/wagner-ann/summary?cid=N00033106&cycle=2024', 'name': 'Ann Wagner', 'state': 'Missouri', 'chamber': 'House', 'party': 'Republican', 'raised': 4213630, 'spent': 2559880, 'cash_on_hand': 3111229, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/walberg-tim/summary?cid=N00026368&cycle=2024', 'name': 'Tim Walberg', 'state': 'Michigan', 'chamber': 'House', 'party': 'Republican', 'raised': 1581866, 'spent': 1735870, 'cash_on_hand': 909451, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/waltz-michael/summary?cid=N00042403&cycle=2024', 'name': 'Michael Waltz', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 2791083, 'spent': 2308327, 'cash_on_hand': 1551925, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/warner-mark/summary?cid=N00002097&cycle=2024', 'name': 'Mark Warner', 'state': 'Virginia', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 4194713, 'spent': 1194595, 'cash_on_hand': 5553233, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/warnock-raphael/summary?cid=N00046489&cycle=2024', 'name': 'Raphael Warnock', 'state': 'Georgia', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 3368621, 'spent': 4483882, 'cash_on_hand': 4738574, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/warren-elizabeth/summary?cid=N00033492&cycle=2024', 'name': 'Elizabeth Warren', 'state': 'Massachusetts', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 8937530, 'spent': 7812058, 'cash_on_hand': 3450046, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/waters-maxine/summary?cid=N00006690&cycle=2024', 'name': 'Maxine Waters', 'state': 'California', 'chamber': 'House', 'party': 'Democrat', 'raised': 1091816, 'spent': 1210992, 'cash_on_hand': 116456, 'debts': 127753}
# {'link': 'https://www.opensecrets.org/members-of-congress/weber-randy/summary?cid=N00033539&cycle=2024', 'name': 'Randy Weber', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 1109496, 'spent': 930820, 'cash_on_hand': 620572, 'debts': 68500}
# {'link': 'https://www.opensecrets.org/members-of-congress/webster-daniel/summary?cid=N00026335&cycle=2024', 'name': 'Daniel Webster', 'state': 'Florida', 'chamber': 'House', 'party': 'Republican', 'raised': 1004827, 'spent': 1132670, 'cash_on_hand': 100028, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/welch-peter/summary?cid=N00000515&cycle=2024', 'name': 'Peter Welch', 'state': 'Vermont', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 314820, 'spent': 561238, 'cash_on_hand': 1713252, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wenstrup-brad/summary?cid=N00033310&cycle=2024', 'name': 'Brad Wenstrup', 'state': 'Ohio', 'chamber': 'House', 'party': 'Republican', 'raised': 618722, 'spent': 1037969, 'cash_on_hand': 459417, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/westerman-bruce/summary?cid=N00035527&cycle=2024', 'name': 'Bruce Westerman', 'state': 'Arkansas', 'chamber': 'House', 'party': 'Republican', 'raised': 2687009, 'spent': 1129000, 'cash_on_hand': 3033560, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wexton-jennifer/summary?cid=N00041002&cycle=2024', 'name': 'Jennifer Wexton', 'state': 'Virginia', 'chamber': 'House', 'party': 'Democrat', 'raised': 480028, 'spent': 733486, 'cash_on_hand': 1544, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/whitehouse-sheldon/summary?cid=N00027533&cycle=2024', 'name': 'Sheldon Whitehouse', 'state': 'Rhode Island', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 4778400, 'spent': 4830918, 'cash_on_hand': 1265387, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wicker-roger/summary?cid=N00003280&cycle=2024', 'name': 'Roger Wicker', 'state': 'Mississippi', 'chamber': 'Senate', 'party': 'Republican', 'raised': 7391861, 'spent': 6950766, 'cash_on_hand': 2994748, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wild-susan/summary?cid=N00041997&cycle=2024', 'name': 'Susan Wild', 'state': 'Pennsylvania', 'chamber': 'House', 'party': 'Democrat', 'raised': 8856117, 'spent': 8841419, 'cash_on_hand': 68659, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/williams-brandon/summary?cid=N00050433&cycle=2024', 'name': 'Brandon Williams', 'state': 'New York', 'chamber': 'House', 'party': 'Republican', 'raised': 4172150, 'spent': 4190243, 'cash_on_hand': 6071, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/williams-nikema-natassha/summary?cid=N00047361&cycle=2024', 'name': 'Nikema Natassha Williams', 'state': 'Georgia', 'chamber': 'House', 'party': 'Democrat', 'raised': 991341, 'spent': 982167, 'cash_on_hand': 13241, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/williams-roger/summary?cid=N00030602&cycle=2024', 'name': 'Roger Williams', 'state': 'Texas', 'chamber': 'House', 'party': 'Republican', 'raised': 1858869, 'spent': 1657531, 'cash_on_hand': 571500, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wilson-frederica/summary?cid=N00030650&cycle=2024', 'name': 'Frederica Wilson', 'state': 'Florida', 'chamber': 'House', 'party': 'Democrat', 'raised': 485427, 'spent': 563079, 'cash_on_hand': 497199, 'debts': 15250}
# {'link': 'https://www.opensecrets.org/members-of-congress/wilson-joe/summary?cid=N00024809&cycle=2024', 'name': 'Joe Wilson', 'state': 'South Carolina', 'chamber': 'House', 'party': 'Republican', 'raised': 875967, 'spent': 1095949, 'cash_on_hand': 44513, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wittman-rob/summary?cid=N00029459&cycle=2024', 'name': 'Rob Wittman', 'state': 'Virginia', 'chamber': 'House', 'party': 'Republican', 'raised': 2793848, 'spent': 1954358, 'cash_on_hand': 1375880, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/womack-steve/summary?cid=N00031857&cycle=2024', 'name': 'Steve Womack', 'state': 'Arkansas', 'chamber': 'House', 'party': 'Republican', 'raised': 2464039, 'spent': 2692460, 'cash_on_hand': 1715893, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/wyden-ron/summary?cid=N00007724&cycle=2024', 'name': 'Ron Wyden', 'state': 'Oregon', 'chamber': 'Senate', 'party': 'Democrat', 'raised': 1523807, 'spent': 3098972, 'cash_on_hand': 1770759, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/yakym-rudy/summary?cid=N00051733&cycle=2024', 'name': 'Rudy Yakym', 'state': 'Indiana', 'chamber': 'House', 'party': 'Republican', 'raised': 3578624, 'spent': 3117157, 'cash_on_hand': 609579, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/young-todd/summary?cid=N00030670&cycle=2024', 'name': 'Todd Young', 'state': 'Indiana', 'chamber': 'Senate', 'party': 'Republican', 'raised': 1717408, 'spent': 1028360, 'cash_on_hand': 4425942, 'debts': 0}
# {'link': 'https://www.opensecrets.org/members-of-congress/zinke-ryan/summary?cid=N00035616&cycle=2024', 'name': 'Ryan Zinke', 'state': 'Montana', 'chamber': 'House', 'party': 'Republican', 'raised': 9990150, 'spent': 9419667, 'cash_on_hand': 680531, 'debts': 0}
# Total objects: 539
# With issues:   0
# []
# 34: Earl Blumenauer

# %% [markdown]
# Function to convert end of year to the actual year

# %%
# We will convert the string '12' or '02' to be 12 and 2 respectively first
# We will then pass it into the function
import datetime

def convert_two_digit_year(year):
    int_year = int(year)
    current_year_two_digit = datetime.datetime.now().year % 100

    if int_year <= current_year_two_digit:
        return 2000 + int_year
    else:
        return 1900 + int_year

# %%
# Function will convert text into valid key
# For example, 'PAC Contributions' will be equal to pac_contributions
import re


def clean_key(raw_string):
    """
    Converts a string into a clean, snake_case format for dictionary keys.
    e.g., "PAC Contributions*" -> "pac_contributions"
    """
    # 1. Convert to lowercase
    s = raw_string.lower()
    # 2. Replace all non-alphanumeric characters (except spaces) with nothing
    s = re.sub(r'[^a-z0-9\s]', '', s)
    # 3. Replace spaces and consecutive spaces with a single underscore
    s = re.sub(r'\s+', '_', s)
    # 4. Remove leading/trailing underscores
    s = s.strip('_')
    return s


print(clean_key(' Contributions*'))
# Out:
# contributions

# %%
# creating a function that will in charge of scraping from the other page
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import re
import time


def scrape_individual_page(link_congressman):

    top_contributors_list = []
    top_industries_list = []
    total_vs_avg_list = []
    sources_of_funds = []

    # This is responsible for getting us to the individual member page
    driver.get("about:blank")  # Clear any existing state
    driver.get(link_congressman)
    page_title = driver.title
    individual_page_src = driver.page_source
    individual_soup = BeautifulSoup(individual_page_src, 'html.parser')


    election_dates = individual_soup.find_all('div', class_="Congress--profile-timeline-item")




    total_vs_avg_list = []

    # Dynamically match the plot group regardless of the number
    chart_for_earned = WebDriverWait(driver, 20).until(
        EC.presence_of_element_located((
            By.CSS_SELECTOR,
            "[class^='raphael-group-'][class$='-plot-group']"
        ))
    )

    # Find all bar elements
    bar_elements = chart_for_earned.find_elements(By.TAG_NAME, 'rect')
    print(f"Found {len(bar_elements)} bars")

    actions = ActionChains(driver)

    for bar in bar_elements:
        try:
            # Hover over each bar to trigger tooltip
            actions.move_to_element(bar).perform()

            # Wait until tooltip is visible
            tooltip_el = WebDriverWait(driver, 14).until(
                EC.visibility_of_element_located((By.CLASS_NAME, "fc__tooltip"))
            )

            # Get tooltip HTML directly
            tooltip_html = tooltip_el.get_attribute("outerHTML")
            tooltip_soup = BeautifulSoup(tooltip_html, "html.parser")

            # Pull all divs from the tooltip
            data_divs = tooltip_soup.find_all('div')
            if not data_divs or len(data_divs) < 4:
                continue


            print(data_divs[0].text.split(','))
            # Extract the numbers
            year = convert_two_digit_year(data_divs[3].text.split(',')[1])
            total_raised_by_congressman = parse_abbreviated_number(data_divs[3].text.split(',')[2])
            average_raised = parse_abbreviated_number(data_divs[0].text.split(',')[-1])

            # Store the result
            total_vs_avg_list.append({
                'year': year,
                'total_raised_by_congressman': total_raised_by_congressman,
                'average_raised': average_raised
            })

        except Exception as e:
            print("Tooltip did not appear:", e)
            continue





    # these will be switched once we loop through all of the links
    print('Here are the election dates', election_dates)
    # This will include information of the election dates



    for item in election_dates:
        date = item.select_one('.Congress--profile-timeline-date')
        label = item.select_one('.Congress--profile-timeline-label')


        date_text = date.get_text(strip=True) if date else None
        label_text = label.get_text(strip=True)

        print("date", date_text)
        print("label", label_text)
        print(repr(label_text), repr(date_text))

        if not label_text:
            continue

        if label_text == 'First Election':
            congress_information[20]['first_election'] = date_text

        elif label_text in ["Last Election", "Next Election", "Retiring at session end"]:
            congress_information[20]["election_type"] = label_text
            congress_information[20]["election_year"] = date_text if date_text and re.fullmatch(r"\d{4}", date_text) else None



    top_industries_contributors_numbers = individual_soup.find_all('div', class_="Congress--profile-top-numbers--info--stats-number")
    top_industries_contributor_names = individual_soup.find_all('div', class_="Congress--profile-top-numbers--info--stats-name")

    # This will have to be cleaned up to remove dollar sign and commas
    congress_information[20]['top_industry'] = top_industries_contributor_names[0].text
    congress_information[20]['top_contributor'] = top_industries_contributor_names[1].text

    # Getting the numbers for the industry and contributor
    congress_information[20]['top_industry_number'] = parse_currency_string(top_industries_contributors_numbers[0].text)
    congress_information[20]['top_contributor_number'] = parse_currency_string(top_industries_contributors_numbers[1].text)


    tables_for_individual_page = individual_soup.find_all('table', class_="js-scrollable")


    contributor_table = tables_for_individual_page[0]
    industries_table = tables_for_individual_page[1]
    # Total vs average raised

    # {year: 12, raised_by_congressman: 1.23, average_raised: 2.44 }

    # If year < 24 and <= 00

    # This will get everything in the contributors table
    for tr in contributor_table.find_all('tr'):
        top_contributors_object = {}
        contributor_row = tr.find_all('td')
        if not contributor_row:
            continue

        top_contributors_object['Contributor'] = contributor_row[0].text
        top_contributors_object['total'] = contributor_row[1].text
        top_contributors_object['individuals'] = contributor_row[2].text
        top_contributors_object['pacs'] = contributor_row[3].text

        top_contributors_list.append(top_contributors_object)
        congress_information[20]['top_contributors'] = top_contributors_list
        congress_information[20]['total_vs_avg'] = total_vs_avg_list



    # This will get everything in the industries table
    for tr in industries_table.find_all('tr'):

        top_industries_object = {}

        industry_row = tr.find_all('td')

        if not industry_row:
            continue

        top_industries_object['industry'] = industry_row[0].text
        top_industries_object['total'] = industry_row[1].text
        top_industries_object['individuals'] = industry_row[2].text
        top_industries_object['pacs'] = industry_row[3].text


        top_industries_list.append(top_industries_object)

        # The index will be changed dynamically soon
        congress_information[20]['top_industries'] = top_industries_list


    table_for_contributions = individual_soup.find_all('div', class_="HorizontalStackedBar")

    all_contribution_data = []
    for div_element in table_for_contributions:

        trs_in_div = div_element.find_all('tr')
        for td in trs_in_div:
            contribution_data = {}
            cells = td.find_all('td')

            contribution_type = cells[0].text
            contribution_amount = cells[1].text
            contribution_percent = cells[2].text


            contribution_data['contribution_type'] = clean_key(contribution_type)
            contribution_data['contribution_amount'] = parse_currency_string(contribution_amount.strip())
            contribution_data['contribution_percent'] = int(float(contribution_percent.strip().strip('%')))

            all_contribution_data.append(contribution_data)


        congress_information[20]['all_contribution_data'] = all_contribution_data













# Class name for hoverables
# fc__tooltip fusioncharts-div
    return page_title
print(scrape_individual_page(congress_information[20]['link']))
print(congress_information[20])
# Out:
# Found 11 bars
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 96', ' $549.77K■\xa0Average Raised by Senate Members - Campaign Committee', ' 96', ' $1.81M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 98', ' $501■\xa0Average Raised by Senate Members - Campaign Committee', ' 98', ' $2.1M']
# Error: '1'
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 08', ' $2.59M■\xa0Average Raised by Senate Members - Campaign Committee', ' 08', ' $3.13M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 10', ' $525.53K■\xa0Average Raised by Senate Members - Campaign Committee', ' 10', ' $3.13M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 12', ' $4.01M■\xa0Average Raised by Senate Members - Campaign Committee', ' 12', ' $3.19M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 14', ' $843.91K■\xa0Average Raised by Senate Members - Campaign Committee', ' 14', ' $3.93M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 16', ' $976.73K■\xa0Average Raised by Senate Members - Campaign Committee', ' 16', ' $3.52M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 18', ' $5.56M■\xa0Average Raised by Senate Members - Campaign Committee', ' 18', ' $5.8M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 20', ' $998.88K■\xa0Average Raised by Senate Members - Campaign Committee', ' 20', ' $10.47M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 22', ' $1.88M■\xa0Average Raised by Senate Members - Campaign Committee', ' 22', ' $9.55M']
# ['■\xa0Total Raised by John Barrasso - Campaign Committee', ' 24', ' $7.71M■\xa0Average Raised by Senate Members - Campaign Committee', ' 24', ' $8.2M']
# Here are the election dates [<div class="Congress--profile-timeline-item">
# <div class="Congress--profile-timeline-label">First Election</div>
# <div class="Congress--profile-timeline-date">2007</div>
# </div>, <div class="Congress--profile-timeline-item Congress--profile-timeline-item--red">
# <div class="Congress--profile-timeline-label">Next Election</div>
# <div class="Congress--profile-timeline-date">2024</div>
# </div>]
# date 2007
# label First Election
# 'First Election' '2007'
# date 2024
# label Next Election
# 'Next Election' '2024'
# Sen. John Barrasso - Campaign Finance Summary • OpenSecrets
# {'link': 'https://www.opensecrets.org/members-of-congress/barrasso-john/summary?cid=N00006236&cycle=2024', 'name': 'John Barrasso', 'state': 'Wyoming', 'chamber': 'Senate', 'party': 'Republican', 'raised': 7710448, 'spent': 4469596, 'cash_on_hand': 7728428, 'debts': 0, 'first_election': '2007', 'election_type': 'Next Election', 'election_year': '2024', 'top_industry': 'Securities & Investment', 'top_contributor': 'Welsh, Carson et al                     ', 'top_industry_number': 1119774, 'top_contributor_number': 72952, 'top_contributors': [{'Contributor': 'Welsh, Carson et al                     ', 'total': '$72,952', 'individuals': '$72,952', 'pacs': '$0'}, {'Contributor': 'Delta Air Lines', 'total': '$59,673', 'individuals': '$49,673', 'pacs': '$10,000'}, {'Contributor': 'DISH Network', 'total': '$51,700', 'individuals': '$41,700', 'pacs': '$10,000'}, {'Contributor': 'Constellation Energy', 'total': '$47,412', 'individuals': '$39,412', 'pacs': '$8,000'}, {'Contributor': 'Neurological Surgery PC', 'total': '$46,000', 'individuals': '$46,000', 'pacs': '$0'}], 'total_vs_avg': [{'year': 1996, 'total_raised_by_congressman': 549770, 'average_raised': 1810000}, {'year': 1998, 'total_raised_by_congressman': None, 'average_raised': 2100000}, {'year': 2008, 'total_raised_by_congressman': 2590000, 'average_raised': 3130000}, {'year': 2010, 'total_raised_by_congressman': 525530, 'average_raised': 3130000}, {'year': 2012, 'total_raised_by_congressman': 4010000, 'average_raised': 3190000}, {'year': 2014, 'total_raised_by_congressman': 843910, 'average_raised': 3930000}, {'year': 2016, 'total_raised_by_congressman': 976730, 'average_raised': 3520000}, {'year': 2018, 'total_raised_by_congressman': 5560000, 'average_raised': 5800000}, {'year': 2020, 'total_raised_by_congressman': 998880, 'average_raised': 10470000}, {'year': 2022, 'total_raised_by_congressman': 1880000, 'average_raised': 9550000}, {'year': 2024, 'total_raised_by_congressman': 7710000, 'average_raised': 8199999}], 'top_industries': [{'industry': 'Securities & Investment', 'total': '$1,119,774', 'individuals': '$970,274', 'pacs': '$149,500'}, {'industry': 'Retired', 'total': '$1,025,596', 'individuals': '$1,025,596', 'pacs': '$0'}, {'industry': 'Oil & Gas', 'total': '$789,401', 'individuals': '$387,676', 'pacs': '$401,725'}, {'industry': 'Health Professionals', 'total': '$513,172', 'individuals': '$264,872', 'pacs': '$248,300'}, {'industry': 'Real Estate', 'total': '$437,644', 'individuals': '$358,144', 'pacs': '$79,500'}], 'all_contribution_data': [{'contribution_type': 'large_individual_contributions', 'contribution_amount': 4352242, 'contribution_percent': 41}, {'contribution_type': 'pac_contributions', 'contribution_amount': 3755695, 'contribution_percent': 35}, {'contribution_type': 'other', 'contribution_amount': 1519718, 'contribution_percent': 14}, {'contribution_type': 'small_individual_contributions_200', 'contribution_amount': 959048, 'contribution_percent': 9}, {'contribution_type': 'candidate_selffinancing', 'contribution_amount': 0, 'contribution_percent': 0}]}

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 driver.close()
#
# NameError: name 'driver' is not defined
